# %%
import numpy as np
calls=np.array([5,6,7,8])
print(calls)
# Out:
# [5 6 7 8]

# %%
dimensional=np.array ( (['jan','feb','mar'],
                       [300,400,500],
                       [600,700,800]))
print(dimensional.shape)
print(dimensional)
# Out:
# (3, 3)
# [['jan' 'feb' 'mar']
#  ['300' '400' '500']
#  ['600' '700' '800']]

# %%
mc=np.array ( (['jan','feb','mar'],
                       [300,400,500],
                       [600,700,800]))
mc[1,1]
# Out:
# np.str_('400')

# %%
sr=np.array([2,3,4,5,6,7])
sr[sr>3]
# Out:
# array([4, 5, 6, 7])

# %%
sr=np.array([2,3,4,5,6,7])
sr[(sr>2) & (sr<4)]
# Out:
# array([3])

# %%
dimensional=np.array ((
    
                       [300,400,500],
                       [600,700,800]))
print(np.sum(dimensional[0:].astype(int)))
# Out:
# 3300

# %%
north = np.array([25,50,75])
south = np.array([100,125,150])
print(np.concatenate((north,south)))
# Out:
# [ 25  50  75 100 125 150]
