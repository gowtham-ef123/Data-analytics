# %%
try:
  age = int(input("enter age:"))
  print(age)
except:
  print("invalid age")
# Out:
# invalid age

# %%
try:
  age = int(input("enter age:"))
  print(age)
except valueError:
  print("invalid age")
except syntaxError:
  print("syntax error")
finally :
  print("completed")
# Out:
# 1969
# completed

# %%
try:
    o=open('sales.csv',"r")
except FilenotfoundError:
    print("file is not available in the system")
finally:
    print("file is available in the folder ")
# Out:
# file is available in the folder
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[52], line 2
#       1 try:
# ----> 2     o=open('sales.csv',"r")
#       3 except FilenotfoundError:
#
# File c:\Users\AnudipCOA\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sales.csv'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 3
#       1 try:
# ...
