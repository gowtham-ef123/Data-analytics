# %%
class employee:
 def work(self):
    print("working")

# %%
class manager(employee):
    pass

m=manager()
m.work()
# Out:
# working

# %%
class employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

employee =employee("kumar", 70000)
employee.salary = 80000
print(employee.salary)
# Out:
# 80000

# %%
class employee:
    def __init__(self, name):
        self.name = name
        self.salary = 50000

employee =employee("kumar")
employee.salary = 80000
print(employee.salary)
# Out:
# 80000

# %%
class employee:
    def __init__(self, name):
        self.name = name
        self.__salary = 50000

employee =employee("kumar")
employee.__salary = 80000
print(employee.__salary)
# Out:
# 80000

# %%
class student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

student = student("kumar", 90)
student.marks = 100
print(student.marks)
# Out:
# 100
