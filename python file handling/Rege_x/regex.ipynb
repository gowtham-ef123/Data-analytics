# %%
import re
text="python is hard"
res=re.search("t",text)
print(res)
# Out:
# <re.Match object; span=(2, 3), match='t'>

# %%
import re 
text="AF087464"
data=re.findall("[A-Z]",text)
print(data)
# Out:
# ['A', 'F']

# %%
import re 
text="AF087464"
data=re.findall("\d+",text)
print(data)
# Out:
# ['087464']

# %%
import re
text="sql power BI"
new=re.sub("power BI","power-bI",text)
print(new)
print(text)
# Out:
# sql power-bI
# sql power BI

# %%
import re
text=("sales:500,profit:100")
new=re.findall("\d",text)
print(new)
# Out:
# ['5', '0', '0', '1', '0', '0']

# %%
import re
text=("tal@.com,ats@,tws@gmail.com")
new=re.findall("\w+@\w.\w+",text)
print(new)
# Out:
# ['yat@gmail', 'tws@gmail']

# %%
import re
num=("9788103128,90801774897,8220258590,9100324162")
new=re.findall("\d{10}",num)
print(new)
# Out:
# ['9788103128', '9080177489', '8220258590', '9100324162']
